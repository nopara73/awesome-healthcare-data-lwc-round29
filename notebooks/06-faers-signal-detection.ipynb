# %% [markdown]
# # FAERS signal detection
#
# Scaffold notebook generated for this repository.

# %%
import pandas as pd
reports = pd.DataFrame({
    "drug":["DRUGA","DRUGA","DRUGB","DRUGB","DRUGB"],
    "event":["NAUSEA","QT_PROLONGATION","NAUSEA","RASH","RASH"],
})
ct = pd.crosstab(reports["drug"], reports["event"])
ct

# %%
# Replace with disproportionality metrics such as PRR/ROR after deduplication.
ct.div(ct.sum(axis=1), axis=0)
