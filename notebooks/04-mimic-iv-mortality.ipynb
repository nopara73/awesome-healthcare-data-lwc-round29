# %% [markdown]
# # MIMIC-IV mortality baseline
#
# Scaffold notebook generated for this repository.

# %%
import pandas as pd
# Replace toy data with MIMIC-IV admissions + ICU stay features after credentialed access.
df = pd.DataFrame({"age":[64,81,57,73], "first_day_lactate":[1.2,4.5,2.0,3.6], "ventilated":[0,1,0,1], "mortality":[0,1,0,1]})
df

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression().fit(df[["age","first_day_lactate","ventilated"]], df["mortality"])
model.predict_proba(df[["age","first_day_lactate","ventilated"]])[:,1]
