# %% [markdown]
# # OMOP ETL walkthrough
#
# Scaffold notebook generated for this repository.

# %%
import pandas as pd
source_conditions = pd.DataFrame({"person_source_value":["p1","p2"], "condition_source_value":["I10","E11.9"]})
# In production, join condition_source_value to Athena CONCEPT/CONCEPT_RELATIONSHIP tables.
source_conditions["condition_source_vocabulary"] = "ICD-10-CM"
source_conditions

# %%
required_columns = ["person_source_value","condition_source_value","condition_source_vocabulary"]
assert set(required_columns).issubset(source_conditions.columns)
